# %%
import tradingeconomics as te

# %%
te.login("51a072f89c934bd:l011saq3ckgd3ka")
# Out:
# 'You are logged in as a 51a072f89c934bd:l011saq3ckgd3ka'

# %%
te.getMarketsData(marketsField = 'commodities', output_type = 'df')
# Out:
#   Symbol Ticker Name                                            Country  Date  \
# 0                     Free accounts have access to the following cou...  None
#
#   State  Last Close CloseDate Group  ... yesterday lastWeek lastMonth  \
# 0  None  None  None      None        ...      None     None      None
#
#   lastYear startYear decimals unit frequency StartDate LastUpdate
# 0     None      None     None           None      None       None
#
# [1 rows x 34 columns]

# %%
te.getMarketsData(marketsField = 'index', output_type = 'df')
# Out:
#          Symbol    Ticker        Name  \
# 0
# 1  NZSE50FG:IND  NZSE50FG      NZX 50
# 2     SET50:IND       SET      SET 50
# 3       OMX:IND       OMX   Stockholm
# 4    MEXBOL:IND    MEXBOL  IPC Mexico
#
#                                              Country                 Date  \
# 0  Free accounts have access to the following cou...                 None
# 1                                        New Zealand  2022-11-25T04:00:12
# 2                                           Thailand  2022-11-25T10:09:00
# 3                                             Sweden  2022-11-25T16:35:00
# 4                                             Mexico  2022-11-25T21:16:00
#
#     State       Last      Close            CloseDate              Group  ...  \
# 0    None        NaN        NaN                 None                     ...
# 1  CLOSED  11382.560  11382.560  2022-11-25T00:00:00    Australia Major  ...
# 2  CLOSED    983.270    983.270  2022-11-25T00:00:00               Asia  ...
# 3  CLOSED   2116.742   2116.742  2022-11-25T00:00:00             Europe  ...
# 4  CLOSED  51668.640  51668.640  2022-11-25T00:00:00  America G20 Major  ...
#
#    yesterday   lastWeek  lastMonth   lastYear  startYear  decimals  unit  \
# 0        NaN        NaN        NaN        NaN        NaN       NaN
# 1  11321.710  11380.610  11046.500  12628.890  13033.770       0.0
# 2    988.130    981.620    967.340    961.930    990.750       0.0
# 3   2106.753   2087.368   1970.065   2242.179   2419.734       0.0
# 4  51979.010  51569.720  49327.110  49492.520  53272.440       0.0
#
#    frequency            StartDate           LastUpdate
# 0       None                 None                 None
# 1    Delayed  2001-01-03T00:00:00  2022-11-25T23:58:00
# 2    Delayed  1995-08-16T00:00:00  2022-11-25T23:59:00
# 3    Delayed  1986-09-30T00:00:00  2022-11-25T23:59:00
# 4    Delayed  1987-01-02T00:00:00  2022-11-25T23:58:00
#
# [5 rows x 34 columns]

# %% [markdown]
# ### To get currency crosses.

# %%
te.getCurrencyCross(cross = 'EUR', output_type = 'df')
# Out:
#   Symbol Ticker Name                                            Country  Date  \
# 0                     Free accounts have access to the following cou...  None
#
#   State  Last Close CloseDate Group  ... yesterday lastWeek lastMonth  \
# 0  None  None  None      None        ...      None     None      None
#
#   lastYear startYear decimals unit frequency StartDate LastUpdate
# 0     None      None     None           None      None       None
#
# [1 rows x 34 columns]

# %% [markdown]
# ### To get stock market data filtered by instrument or multiple instruments.

# %%
te.getMarketsBySymbol(symbols='aapl:us')
# Out:
# [{'Symbol': '',
#   'Ticker': '',
#   'Name': '',
#   'Country': 'Free accounts have access to the following countries: Mexico, New Zealand, Sweden, Thailand. For more, contact us at support@tradingeconomics.com.',
#   'Date': None,
#   'Type': '',
#   'decimals': None,
#   'state': None,
#   'Last': None,
#   'Close': None,
#   'CloseDate': None,
#   'MarketCap': None,
#   'URL': '',
#   'Importance': None,
#   'DailyChange': None,
#   'DailyPercentualChange': None,
#   'WeeklyChange': None,
#   'WeeklyPercentualChange': None,
#   'MonthlyChange': None,
#   'MonthlyPercentualChange': None,
#   'YearlyChange': None,
#   'YearlyPercentualChange': None,
#   'YTDChange': None,
#   'YTDPercentualChange': None,
#   'day_high': None,
#   'day_low': None,
#   'yesterday': None,
#   'lastWeek': None,
#   'lastMonth': None,
#   'lastYear': None,
#   'startYear': None,
#   'ISIN': '',
#   'unit': None,
#   'frequency': None,
#   'LastUpdate': None}]

# %%
te.getMarketsBySymbol(symbols=['aapl:us', 'gac:com'], output_type='raw')
# Out:
# [{'Symbol': '',
#   'Ticker': '',
#   'Name': '',
#   'Country': 'Free accounts have access to the following countries: Mexico, New Zealand, Sweden, Thailand. For more, contact us at support@tradingeconomics.com.',
#   'Date': None,
#   'Type': '',
#   'decimals': None,
#   'state': None,
#   'Last': None,
#   'Close': None,
#   'CloseDate': None,
#   'MarketCap': None,
#   'URL': '',
#   'Importance': None,
#   'DailyChange': None,
#   'DailyPercentualChange': None,
#   'WeeklyChange': None,
#   'WeeklyPercentualChange': None,
#   'MonthlyChange': None,
#   'MonthlyPercentualChange': None,
#   'YearlyChange': None,
#   'YearlyPercentualChange': None,
#   'YTDChange': None,
#   'YTDPercentualChange': None,
#   'day_high': None,
#   'day_low': None,
#   'yesterday': None,
#   'lastWeek': None,
#   'lastMonth': None,
#   'lastYear': None,
#   'startYear': None,
#   'ISIN': '',
#   'unit': None,
#   'frequency': None,
#   'LastUpdate': None}]

# %% [markdown]
# ### To get the peer group of a stock or a group of stocks

# %%
te.getMarketsPeers(symbols='aapl:us', output_type='df')
# Out:
#   Symbol Ticker Name                                            Country  Date  \
# 0                     Free accounts have access to the following cou...  None
#
#   Type decimals state  Last Close  ... day_low yesterday lastWeek lastMonth  \
# 0          None  None  None  None  ...    None      None     None      None
#
#   lastYear startYear ISIN  unit frequency LastUpdate
# 0     None      None       None      None       None
#
# [1 rows x 35 columns]

# %% [markdown]
# ### To get a list of stocks by country

# %%
te.getStocksByCountry(country='mexico',output_type='df')
# Out:
#           Symbol                                 Name Country    Type  \
# 0        VLRS:US               Controladorauelaavcncv  Mexico  stocks
# 1          TV:US                   Grupo Televisa Sab  Mexico  stocks
# 2         SIM:US                Grupo Simec Sab De Cv  Mexico  stocks
# 3     SANMEXB:MM              Santander M&eacute;xico  Mexico  stocks
# 4      PINFRA:MM                               Pinfra  Mexico  stocks
# 5         PAC:US     Grupo Aeroportuario Del Pacifico  Mexico  stocks
# 6        OMAB:US  Grupo Aeroportuario Del Centro Nort  Mexico  stocks
# 7     MEXBOL:IND                           IPC Mexico  Mexico   index
# 8        LABB:MM            Genomma Lab Internacional  Mexico  stocks
# 9         KOF:US            Coca Cola Femsa Sab De Cv  Mexico  stocks
# 10    KIMBERA:MM      Kimberly-Clark de M&eacute;xico  Mexico  stocks
# 11       ICHB:MM                        Industrias CH  Mexico  stocks
# 12        IBA:US         Industrias Bachoco Sab De Cv  Mexico  stocks
# 13     GRUMAB:MM                                GRUMA  Mexico  stocks
# 14  GMXN10YR:IND                           Mexico 10Y  Mexico    bond
# 15   GMEXICOB:MM                  Grupo M&eacute;xico  Mexico  stocks
# 16   GFNORTEO:MM                              Banorte  Mexico  stocks
# 17   GFINBURO:MM                              Inbursa  Mexico  stocks
# 18   GCARSOA1:MM                          Grupo Carso  Mexico  stocks
# 19       GAPB:MM     Grupo Aeroportuario del Pacifico  Mexico  stocks
# 20       FRES:LN                            Fresnillo  Mexico  stocks
# 21        FMX:US       Fomento Economico Mexicano Sab  Mexico  stocks
# 22         CX:US                      Cemex Sab De Cv  Mexico  stocks
# 23       BSMX:US   Santander Mexico Fincl Gp Sab Decv  Mexico  stocks
# 24     BOLSAA:MM            Bolsa Mexicana de Valores  Mexico  stocks
# 25     BIMBOA:MM                          Grupo Bimbo  Mexico  stocks
# 26      ASURB:MM      Grupo Aeroportuario del Sureste  Mexico  stocks
# 27        ASR:US      Grupo Aeroportuario Del Sureste  Mexico  stocks
# 28       AMXL:MM                        América Móvil  Mexico  stocks
# 29        AMX:US          America Movil Sab De Cv Amx  Mexico  stocks
# 30       AMOV:US              America Movil Sab De Cv  Mexico  stocks
# 31     ALPEKA:MM                                Alpek  Mexico  stocks
# 32      ALFAA:MM                                 Alfa  Mexico  stocks
# 33         AC:MM                     Arca Continental  Mexico  stocks
#
#                               URL Frequency
# 0                        /vlrs:us     Daily
# 1                          /tv:us     Daily
# 2                         /sim:us     Daily
# 3                     /sanmexb:mm     Daily
# 4                     /pinfra*:mm     Daily
# 5                         /pac:us     Daily
# 6                        /omab:us     Daily
# 7            /mexico/stock-market   Delayed
# 8                        /labb:mm     Daily
# 9                         /kof:us     Daily
# 10                    /kimbera:mm     Daily
# 11                       /ichb:mm     Daily
# 12                        /iba:us     Daily
# 13                     /grumab:mm     Daily
# 14  /mexico/government-bond-yield   Delayed
# 15                   /gmexicob:mm     Daily
# 16                   /gfnorteo:mm     Daily
# 17                   /gfinburo:mm     Daily
# 18                   /gcarsoa1:mm     Daily
# 19                       /gapb:mm     Daily
# 20                       /fres:ln     Daily
# 21                        /fmx:us     Daily
# 22                         /cx:us     Daily
# 23                       /bsmx:us     Daily
# 24                     /bolsaa:mm     Daily
# 25                     /bimboa:mm     Daily
# 26                      /asurb:mm     Daily
# 27                        /asr:us     Daily
# 28                       /amxl:mm     Daily
# 29                        /amx:us     Daily
# 30                       /amov:us     Daily
# 31                     /alpeka:mm     Daily
# 32                      /alfaa:mm     Daily
# 33                        /ac*:mm     Daily

# %% [markdown]
# ### To get components of the certain index:

# %%
te.getMarketsComponents(symbols='psi20:ind', output_type='df')
# Out:
#   Symbol Ticker Name                                            Country  Date  \
# 0                     Free accounts have access to the following cou...  None
#
#   Type decimals state  Last Close  ... day_low yesterday lastWeek lastMonth  \
# 0          None  None  None  None  ...    None      None     None      None
#
#   lastYear startYear ISIN  unit frequency LastUpdate
# 0     None      None       None      None       None
#
# [1 rows x 35 columns]

# %% [markdown]
# Output:
#      Symbol         ...                    LastUpdate
# 0   ALTR:PL         ...           2018-06-28T13:45:00
# 1    BCP:PL         ...           2018-06-28T13:45:00
# 2    COR:PL         ...           2018-06-28T13:48:00
#         ...         ...                           ...
# 15   SEM:PL         ...           2018-06-28T13:47:00
# 16   SON:PL         ...           2018-06-28T13:46:00
# 17  SONC:PL         ...           2018-06-28T11:51:00

# %% [markdown]
# ### To get components of the group of indexes:

# %%
te.getMarketsComponents(symbols=['indu:ind', 'psi20:ind'])
# Out:
# [{'Symbol': '',
#   'Ticker': '',
#   'Name': '',
#   'Country': 'Free accounts have access to the following countries: Mexico, New Zealand, Sweden, Thailand. For more, contact us at support@tradingeconomics.com.',
#   'Date': None,
#   'Type': '',
#   'decimals': None,
#   'state': None,
#   'Last': None,
#   'Close': None,
#   'CloseDate': None,
#   'MarketCap': None,
#   'URL': '',
#   'Importance': None,
#   'DailyChange': None,
#   'DailyPercentualChange': None,
#   'WeeklyChange': None,
#   'WeeklyPercentualChange': None,
#   'MonthlyChange': None,
#   'MonthlyPercentualChange': None,
#   'YearlyChange': None,
#   'YearlyPercentualChange': None,
#   'YTDChange': None,
#   'YTDPercentualChange': None,
#   'day_high': None,
#   'day_low': None,
#   'yesterday': None,
#   'lastWeek': None,
#   'lastMonth': None,
#   'lastYear': None,
#   'startYear': None,
#   'ISIN': '',
#   'unit': None,
#   'frequency': None,
#   'LastUpdate': None}]

# %% [markdown]
# Output:
#      Symbol         ...                    LastUpdate
# 0   AAPL:US         ...           2018-06-28T13:49:00
# 1   ALTR:PL         ...           2018-06-28T13:45:00
# 2    AXP:US         ...           2018-06-28T13:49:00
#         ...         ...                           ...
# 45    VZ:US         ...           2018-06-28T13:49:00
# 46   WMT:US         ...           2018-06-28T13:49:00
# 47   XOM:US         ...           2018-06-28T13:49:00

# %% [markdown]
# ### To get Stock descriptions by company symbol:

# %%
te.getMarketsStockDescriptions(symbol='aapl:us', output_type='df')
# Out:
#     Symbol   Name                                        Description  \
# 0  AAPL:US  Apple  Apple Inc. (Apple) designs, manufactures and m...
#
#          Country                  Sector                         Industry  \
# 0  United States  Information Technology  Technology Hardware & Equipment
#
#                                   Subindustry
# 0  Technology Hardware, Storage & Peripherals

# %% [markdown]
# ### To get Stock descriptions by country:

# %%
te.getMarketsStockDescriptions(country='mexico', output_type='df')
# Out:
#          Symbol                                 Name  \
# 0       VLRS:US               Controladorauelaavcncv
# 1         TV:US                   Grupo Televisa Sab
# 2        SIM:US                Grupo Simec Sab De Cv
# 3    SANMEXB:MM              Santander M&eacute;xico
# 4     PINFRA:MM                               Pinfra
# 5        PAC:US     Grupo Aeroportuario Del Pacifico
# 6       OMAB:US  Grupo Aeroportuario Del Centro Nort
# 7       LABB:MM            Genomma Lab Internacional
# 8        KOF:US            Coca Cola Femsa Sab De Cv
# 9    KIMBERA:MM      Kimberly-Clark de M&eacute;xico
# 10      ICHB:MM                        Industrias CH
# 11       IBA:US         Industrias Bachoco Sab De Cv
# 12    GRUMAB:MM                                GRUMA
# 13  GMEXICOB:MM                  Grupo M&eacute;xico
# 14  GFNORTEO:MM                              Banorte
# 15  GFINBURO:MM                              Inbursa
# 1           Communications                         Media
# 2                Materials                  Iron & Steel
# 3
# 4                                     Heavy Construction
# 5              Industrials    Transportation & Logistics
# 6              Industrials    Transportation & Logistics
# 7              Health Care              Biotech & Pharma
# 8         Consumer Staples             Consumer Products
# 9
# 10               Materials                  Iron & Steel
# 11        Consumer Staples             Consumer Products
# 12        Consumer Staples             Consumer Products
# 13
# 14              Financials                       Banking
# 15              Financials                       Banking
# 16        Consumer Staples     Retail - Consumer Staples
# 17             Industrials    Transportation & Logistics
# 18               Materials               Metals & Mining
# 19        Consumer Staples             Consumer Products
# 20               Materials        Construction Materials
# 21              Financials                       Banking
# 22              Financials  Institutional Financial Svcs
# 23        Consumer Staples             Consumer Products
# 24             Industrials    Transportation & Logistics
# 25             Industrials    Transportation & Logistics
# 26
# 27          Communications                       Telecom
# 28          Communications                       Telecom
# 29               Materials                     Chemicals
# 30               Materials                     Chemicals
# 31                                           Soft Drinks
#
#                       Subindustry
# 0                        Airlines
# 1       Publishing & Broadcasting
# 2                 Steel Producers
# 3
# 4
# 5      Transport Support Services
# 6      Transport Support Services
# 7                Specialty Pharma
# 8                       Beverages
# 9
# 10                Steel Producers
# 11                  Packaged Food
# 12                  Packaged Food
# 13
# 14                          Banks
# 15                          Banks
# 16                 Mass Merchants
# 17     Transport Support Services
# 18          Precious Metal Mining
# 19                      Beverages
# 20            Cement & Aggregates
# 21                          Banks
# 22     Security & Cmdty Exchanges
# 23                  Packaged Food
# 24     Transport Support Services
# 25     Transport Support Services
# 26
# 27               Telecom Carriers
# 28               Telecom Carriers
# 29  Basic & Diversified Chemicals
# 30  Basic & Diversified Chemicals
# 31

# %% [markdown]
# ### To search markets by country.

# %%
te.getMarketsSearch(country='mexico',output_type="df")
# Out:
#           Symbol    Ticker                                 Name  \
# 0
# 1        VLRS:US      VLRS               Controladorauelaavcncv
# 2          TV:US     TV:US                   Grupo Televisa Sab
# 3         SIM:US    SIM:US                Grupo Simec Sab De Cv
# 4     SANMEXB:MM   SANMEXB              Santander M&eacute;xico
# 5         PAC:US    PAC:US     Grupo Aeroportuario Del Pacifico
# 6        OMAB:US   OMAB:US  Grupo Aeroportuario Del Centro Nort
# 7     MEXBOL:IND    MEXBOL                           IPC Mexico
# 8        LABB:MM      LABB            Genomma Lab Internacional
# 9         KOF:US    KOF:US            Coca Cola Femsa Sab De Cv
# 10    KIMBERA:MM   KIMBERA      Kimberly-Clark de M&eacute;xico
# 11       ICHB:MM      ICHB                        Industrias CH
# 12        IBA:US       IBA         Industrias Bachoco Sab De Cv
# 13     GRUMAB:MM    GRUMAB                                GRUMA
# 14  GMXN10YR:IND  GMXN10YR                           Mexico 10Y
# 15   GMEXICOB:MM  GMEXICOB                  Grupo M&eacute;xico
# 16   GFNORTEO:MM  GFNORTEO                              Banorte
# 17   GFINBURO:MM  GFINBURO                              Inbursa
# 18   GCARSOA1:MM  GCARSOA1                          Grupo Carso
# 19       GAPB:MM      GAPB     Grupo Aeroportuario del Pacifico
# 20       FRES:LN      FRES                            Fresnillo
# 21        FMX:US       FMX       Fomento Economico Mexicano Sab
# 22         CX:US        CX                      Cemex Sab De Cv
# 12  stocks       2.0    OPEN     51.50     51.50  ...     51.50     52.2550
# 13  stocks       2.0    OPEN    234.31    234.31  ...    232.95    240.5300
# 14    bond       4.0    OPEN      9.13      9.13  ...      9.13      9.0900
# 15  stocks       2.0    OPEN     71.11     71.11  ...     69.50     72.9300
# 16  stocks       2.0    OPEN    156.54    156.54  ...    149.88    153.4900
# 17  stocks       2.0    OPEN     36.72     36.72  ...     36.20     37.4300
# 18  stocks       2.0    OPEN     82.59     82.59  ...     82.01     83.6800
# 19  stocks       2.0    OPEN    311.47    311.47  ...    309.01    312.8400
# 20  stocks       2.0  CLOSED    895.40    895.40  ...    886.20    899.6000
# 21  stocks       2.0    OPEN     79.78     79.78  ...     77.53     80.0900
# 22  stocks       2.0    OPEN      4.54      4.54  ...      4.52      4.5700
# 23  stocks       2.0    OPEN      6.11      6.11  ...      6.04      6.2100
# 24  stocks       2.0    OPEN     37.61     37.61  ...     37.33     37.4500
# 25  stocks       2.0    OPEN     86.45     86.45  ...     82.00     87.2600
# 26  stocks       2.0    OPEN    473.56    473.56  ...    463.21    472.3900
# 27  stocks       2.0    OPEN    240.40    240.40  ...    239.50    241.5000
# 28  stocks       2.0    OPEN     19.77     19.77  ...     19.69     19.9200
# 29  stocks       2.0    OPEN     20.50     20.50  ...     20.30     20.4400
# 30  stocks       2.0    OPEN     20.50     20.50  ...     20.30     20.4400
# 31  stocks       2.0    OPEN     28.11     28.11  ...     27.75     28.2100
# 32  stocks       2.0    OPEN     13.94     13.94  ...     13.76     14.1700
#
#      lastWeek  lastMonth    lastYear  startYear          ISIN     unit  \
# 0         NaN        NaN         NaN        NaN                   None
# 1       9.980       8.17     14.7800     17.970  US21240E1055      USD
# 2       5.400       5.18      9.0700      9.370  US40049J2069      USD
# 3      31.610      30.11     22.8600     27.000  US4004911065      USD
# 4      22.990      23.23     26.3000     23.540  MXP690491412      MXN
# 5     163.320     147.23    116.9800    137.470  US4005061019      USD
# 6      69.790      63.12     47.2700     53.690  US4005011022      USD
# 7   51569.720   49327.11  49492.5200  53272.440
# 8      15.790      14.38     18.0600     21.480  MX01LA010006      MXN
# 9      68.940      62.15     47.5300     54.790  US1912411089      USD
# 10     32.910      29.47     32.2300     31.010  MXP606941179      MXN
# 11    203.350     216.50    175.9800    190.890  MXP524131127      MXN
# 12     52.500      48.90     39.8898     42.540  US4564631087      USD
# 13    234.370     230.59    258.9100    262.520  MXP4948K1056      MXN
# 14      9.285       9.78      7.6640      7.564                percent
# 15     75.050      71.65     84.6500     89.290  MXP370841019      MXN
# 16    152.840     159.81    125.2000    133.020  MXP370711014      MXN
# 17     37.480      37.29     20.0500     24.520  MXP370641013      MXN
# 18     86.920      77.14     59.5000     66.190  MXP461181085      MXN
# 19    318.700     294.28    250.0300    282.160  MX01GA000004      MXN
# 20    865.400     745.00    906.8000    892.800  GB00B2QPKJ12      GBp
# 21     79.600      69.90     72.2500     77.710  US3444191064      USD
# 22      4.500       3.70      5.8500      6.780  US1512908898      USD
# 23      6.150       5.65      6.0300      5.640  US40053C1053      USD
# 24     37.380      35.91     33.8800     38.920  MX01BM1B0000      MXN
# 25     87.560      74.72     54.4300     62.970  MXP495211262      MXN
# 26    470.930     445.59    391.4600    422.760  MXP001661018      MXN
# 27    241.520     222.86    181.7500    206.160  US40051E2028      USD
# 28     19.460      18.43     18.6100     21.690  MXP001691213      MXN
# 29     19.960      18.38     17.0700     21.110  US02364W1053      USD
# 30     19.960      18.38     17.0700     21.110  US02364W2044      USD
# 31     28.090      27.36     20.1400     22.280  MX01AL0C0004      MXN
# 32     14.150      13.13     15.9500     15.020  MXP000511016      MXN
#
#     frequency           LastUpdate
# 0        None                 None
# 1       Daily  2022-11-25T22:48:00
# 2       Daily  2022-11-26T00:15:00
# 3       Daily  2022-11-26T00:08:00
# 4       Daily  2022-11-26T00:07:00
# 5       Daily  2022-11-25T22:29:00
# 6       Daily  2022-11-25T22:28:00
# 7     Delayed  2022-11-25T23:58:00
# 8       Daily  2022-11-25T23:50:00
# 9       Daily  2022-11-25T22:18:00
# 10      Daily  2022-11-25T23:49:00
# 11      Daily  2022-11-25T23:48:00
# 12      Daily  2022-11-25T22:16:00
# 13      Daily  2022-11-25T23:45:00
# 14    Delayed  2022-11-25T23:00:00
# 15      Daily  2022-11-25T23:45:00
# 16      Daily  2022-11-25T23:44:00
# 17      Daily  2022-11-25T23:44:00
# 18      Daily  2022-11-25T23:44:00
# 19      Daily  2022-11-25T23:44:00
# 20      Daily  2022-11-25T22:09:00
# 21      Daily  2022-11-25T21:54:00
# 22      Daily  2022-11-25T21:54:00
# 23      Daily  2022-11-25T21:53:00
# 24      Daily  2022-11-25T23:39:00
# 25      Daily  2022-11-25T23:38:00
# 26      Daily  2022-11-25T23:38:00
# 27      Daily  2022-11-25T21:49:00
# 28      Daily  2022-11-25T23:38:00
# 29      Daily  2022-11-25T21:48:00
# 30      Daily  2022-11-25T21:47:00
# 31      Daily  2022-11-25T23:38:00
# 32      Daily  2022-11-25T23:38:00
#
# [33 rows x 35 columns]

# %% [markdown]
# ### To search markets by country and category.

# %%
te.getMarketsSearch(term='japan', category = 'index')
### Syntax Error term
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 te.getMarketsSearch(term='japan', category = 'index')
#
# TypeError: getMarketsSearch() got an unexpected keyword argument 'term'

# %% [markdown]
# ### To search markets by country and categories.

# %%
te.getMarketsSearch(term='japan', category = ['index', 'markets'])
### Syntax Error term
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 te.getMarketsSearch(term='japan', category = ['index', 'markets'])
#
# TypeError: getMarketsSearch() got an unexpected keyword argument 'term'

# %% [markdown]
# ### To get stocks symbology.

# %%
te.getMarketsSymbology(symbol = 'aapl:us', output_type = 'df')
# Out:
#     Symbol Ticker          ISIN   Name        Country
# 0  AAPL:US   AAPL  US0378331005  Apple  United States

# %%
te.getMarketsSymbology(ticker = 'aapl', output_type = 'df')
# Out:
#     Symbol Ticker          ISIN   Name        Country
# 0  AAPL:US   AAPL  US0378331005  Apple  United States

# %%
te.getMarketsSymbology(isin = 'US0378331005', output_type = 'df')
# Out:
#     Symbol Ticker          ISIN   Name        Country
# 0  AAPL:US   AAPL  US0378331005  Apple  United States
